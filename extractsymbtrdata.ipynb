# %%
from symbtrdataextractor import extractor
from symbtrdataextractor import symbtrreader
import os
import json
import pprint

# %%
txtfilename = os.path.join('sampledata','kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.txt')
autoSegfile = os.path.join('sampledata','kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.autoSeg')

scorename = os.path.splitext(os.path.basename(txtfilename))[0]
mbid = 'b43fd61e-522c-4af4-821d-db85722bf48c'
autoSegBounds = json.load(open(autoSegfile,'r'))['boundary_noteIdx']

txtdata, isDataValid = extractor.extract(txtfilename, symbtrname=scorename, seg_note_idx=autoSegBounds,
                            mbid=mbid, extract_all_labels=False, melody_sim_thres=0.25, 
                            lyrics_sim_thres=0.25, get_recording_rels=False)

# %%
mu2filename = os.path.join('sampledata','kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.mu2')
mu2header, headerRow, isHederValid = symbtrreader.readMu2Header(mu2filename, symbtrname=scorename)

# %%
data = extractor.merge(txtdata, mu2header)
pprint.pprint(data)
# Out:
# {'composer': {'mbid': '9157531e-ba32-46e7-8c60-1a66c99f2ace',
#               'mu2_name': u'Tatyos Efendi',
#               'name': u'Tateos E\xf1serciyan',
#               'symbtr_slug': 'tatyos_efendi'},
#  'form': {'mb_attribute': u'\u015eark\u0131',
#           'mu2_name': u'\u015eark\u0131',
#           'symbtr_slug': 'sarki'},
#  'genre': 'classical',
#  'key_signature': [u'B4b5', u'E5b5', u'A4b5'],
#  'language': 'ota',
#  'lyricist': {'mbid': '125ec42a-7229-4250-afc5-e057484327fe',
#               'mu2_name': u'?',
#               'name': '[unknown]'},
#  'makam': {'mb_attribute': u'K\xfcrdilihicazkar',
#            'mu2_name': u'K\xfcrd\xeelihicazk\xe2r',
#            'symbtr_slug': 'kurdilihicazkar'},
#  'notation': u'TSM',
#  'phrases': {'annotated': [{'endNote': 15,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'A1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 2},
#                            {'endNote': 21,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'B1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 16},
#                            {'endNote': 28,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'C1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 22},
#                            {'endNote': 39,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'D1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 29},
#                            {'endNote': 45,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'E1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 40},
#                            {'endNote': 60,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'F1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 46},
#                            {'endNote': 72,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'G1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 61},
#                            {'endNote': 81,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'H1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 73},
#                            {'endNote': 90,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'I1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 82},
#                            {'endNote': 98,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'J1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 91},
#                            {'endNote': 104,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'E1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 99},
#                            {'endNote': 119,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'A2',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 105},
#                            {'endNote': 125,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'B1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 120},
#                            {'endNote': 132,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'C1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 126},
#                            {'endNote': 143,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'D1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 133},
#                            {'endNote': 149,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'E1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 144},
#                            {'endNote': 164,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'F1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 150},
#                            {'endNote': 176,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'G1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 165},
#                            {'endNote': 185,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'H1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 177},
#                            {'endNote': 194,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'I1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 186},
#                            {'endNote': 202,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'J2',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 195},
#                            {'endNote': 206,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'K1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 203},
#                            {'endNote': 208,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'L1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 207},
#                            {'endNote': 213,
#                             'flavor': [],
#                             'lyricStructure': u'B1',
#                             'lyrics': u'Ehl_i a\u015f',
#                             'melodicStructure': u'M1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 209},
#                            {'endNote': 227,
#                             'flavor': [],
#                             'lyricStructure': u'C1',
#                             'lyrics': u'k\u0131n ',
#                             'melodicStructure': u'N1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 214},
#                            {'endNote': 244,
#                             'flavor': [],
#                             'lyricStructure': u'D1',
#                             'lyrics': u'ne\u015fveg\xe2h\u0131 ',
#                             'melodicStructure': u'O1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 228},
#                            {'endNote': 269,
#                             'flavor': [],
#                             'lyricStructure': u'E1',
#                             'lyrics': u'k\xfb\u015fe_i mey',
#                             'melodicStructure': u'P1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 245},
#                            {'endNote': 281,
#                             'flavor': [],
#                             'lyricStructure': u'F1',
#                             'lyrics': u'hanedir  ',
#                             'melodicStructure': u'Q1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 270},
#                            {'endNote': 293,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'R1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 282},
#                            {'endNote': 313,
#                             'flavor': [],
#                             'lyricStructure': u'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'S1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 294},
#                            {'endNote': 325,
#                             'flavor': [],
#                             'lyricStructure': u'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': u'T1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 314},
#                            {'endNote': 340,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'U1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 326},
#                            {'endNote': 368,
#                             'flavor': [],
#                             'lyricStructure': u'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': u'V1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 341},
#                            {'endNote': 379,
#                             'flavor': [],
#                             'lyricStructure': u'J1',
#                             'lyrics': u'm\xe2ne',
#                             'melodicStructure': u'W1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 369},
#                            {'endNote': 387,
#                             'flavor': [],
#                             'lyricStructure': u'K1',
#                             'lyrics': u'dir  ',
#                             'melodicStructure': u'X1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 380},
#                            {'endNote': 393,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'Y1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 388},
#                            {'endNote': 413,
#                             'flavor': [],
#                             'lyricStructure': u'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'S1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 394},
#                            {'endNote': 425,
#                             'flavor': [],
#                             'lyricStructure': u'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': u'T1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 414},
#                            {'endNote': 440,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'U1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 426},
#                            {'endNote': 468,
#                             'flavor': [],
#                             'lyricStructure': u'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': u'V1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 441},
#                            {'endNote': 481,
#                             'flavor': [],
#                             'lyricStructure': u'L1',
#                             'lyrics': u'm\xe2nedir  ',
#                             'melodicStructure': u'Z1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 469},
#                            {'endNote': 494,
#                             'flavor': [u'nev`eser@sol4'],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'\xc01',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 482},
#                            {'endNote': 505,
#                             'flavor': [],
#                             'lyricStructure': u'M1',
#                             'lyrics': u'G\xfcft_\xfc g\xfby_i ',
#                             'melodicStructure': u'\xc11',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 495},
#                            {'endNote': 516,
#                             'flavor': [u'nikriz@do5'],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'\xc21',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 506},
#                            {'endNote': 537,
#                             'flavor': [],
#                             'lyricStructure': u'N1',
#                             'lyrics': u'\xe2leme al',
#                             'melodicStructure': u'\xc31',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 517},
#                            {'endNote': 546,
#                             'flavor': [],
#                             'lyricStructure': u'O1',
#                             'lyrics': u'danma hep ',
#                             'melodicStructure': u'\xc41',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 538},
#                            {'endNote': 560,
#                             'flavor': [],
#                             'lyricStructure': u'P1',
#                             'lyrics': u'ef',
#                             'melodicStructure': u'\xc51',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 547},
#                            {'endNote': 572,
#                             'flavor': [],
#                             'lyricStructure': u'F2',
#                             'lyrics': u'sanedir  ',
#                             'melodicStructure': u'Q1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 561},
#                            {'endNote': 584,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'R1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 573},
#                            {'endNote': 604,
#                             'flavor': [],
#                             'lyricStructure': u'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'S1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 585},
#                            {'endNote': 616,
#                             'flavor': [],
#                             'lyricStructure': u'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': u'T1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 605},
#                            {'endNote': 631,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'U1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 617},
#                            {'endNote': 659,
#                             'flavor': [],
#                             'lyricStructure': u'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': u'V1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 632},
#                            {'endNote': 670,
#                             'flavor': [],
#                             'lyricStructure': u'J1',
#                             'lyrics': u'm\xe2ne',
#                             'melodicStructure': u'W1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 660},
#                            {'endNote': 672,
#                             'flavor': [],
#                             'lyricStructure': u'K1',
#                             'lyrics': u'dir  ',
#                             'melodicStructure': u'\xc61',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 671}],
#              'automatic': [{'endNote': 5,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'A1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 2},
#                            {'endNote': 14,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'B1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 6},
#                            {'endNote': 40,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'C1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 15},
#                            {'endNote': 98,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'D1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 41},
#                            {'endNote': 107,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'E1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 99},
#                            {'endNote': 133,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'F1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 108},
#                            {'endNote': 186,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'G1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 134},
#                            {'endNote': 189,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'H1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 187},
#                            {'endNote': 203,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'I1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 190},
#                            {'endNote': 219,
#                             'flavor': [],
#                             'lyricStructure': u'B1',
#                             'lyrics': u'Ehl_i a\u015fk\u0131n ',
#                             'melodicStructure': u'J1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 204},
#                            {'endNote': 229,
#                             'flavor': [],
#                             'lyricStructure': u'C1',
#                             'lyrics': u'ne\u015f',
#                             'melodicStructure': u'K1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 220},
#                            {'endNote': 242,
#                             'flavor': [],
#                             'lyricStructure': u'D1',
#                             'lyrics': u'veg\xe2h\u0131 ',
#                             'melodicStructure': u'L1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 230},
#                            {'endNote': 253,
#                             'flavor': [],
#                             'lyricStructure': u'E1',
#                             'lyrics': u'k\xfb\u015fe_i ',
#                             'melodicStructure': u'M1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 243},
#                            {'endNote': 265,
#                             'flavor': [],
#                             'lyricStructure': u'F1',
#                             'lyrics': u'mey',
#                             'melodicStructure': u'N1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 254},
#                            {'endNote': 283,
#                             'flavor': [],
#                             'lyricStructure': u'G1',
#                             'lyrics': u'hanedir  ',
#                             'melodicStructure': u'O1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'B1',
#                                           'melodicStructure': u'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 266},
#                            {'endNote': 308,
#                             'flavor': [],
#                             'lyricStructure': u'H1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'P1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 284},
#                            {'endNote': 335,
#                             'flavor': [],
#                             'lyricStructure': u'I1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': u'Q1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 309},
#                            {'endNote': 346,
#                             'flavor': [],
#                             'lyricStructure': u'J1',
#                             'lyrics': u'eyleyen ',
#                             'melodicStructure': u'R1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 336},
#                            {'endNote': 358,
#                             'flavor': [],
#                             'lyricStructure': u'K1',
#                             'lyrics': u'pey',
#                             'melodicStructure': u'S1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 347},
#                            {'endNote': 376,
#                             'flavor': [],
#                             'lyricStructure': u'L1',
#                             'lyrics': u'm\xe2',
#                             'melodicStructure': u'T1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 359},
#                            {'endNote': 401,
#                             'flavor': [],
#                             'lyricStructure': u'M1',
#                             'lyrics': u'nedir  S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'U1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 377},
#                            {'endNote': 428,
#                             'flavor': [],
#                             'lyricStructure': u'I1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': u'V1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 402},
#                            {'endNote': 439,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': u'W1',
#                             'name': u'INSTRUMENTAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'INSTRUMENTAL_PHRASE',
#                             'startNote': 429},
#                            {'endNote': 451,
#                             'flavor': [],
#                             'lyricStructure': u'N1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': u'X1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 440},
#                            {'endNote': 469,
#                             'flavor': [],
#                             'lyricStructure': u'L1',
#                             'lyrics': u'm\xe2',
#                             'melodicStructure': u'Y1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 452},
#                            {'endNote': 489,
#                             'flavor': [u'nev`eser@sol4'],
#                             'lyricStructure': u'O1',
#                             'lyrics': u'nedir  ',
#                             'melodicStructure': u'Z1',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 470},
#                            {'endNote': 510,
#                             'flavor': [u'nikriz@do5'],
#                             'lyricStructure': u'P1',
#                             'lyrics': u'G\xfcft_\xfc g\xfby_i ',
#                             'melodicStructure': u'\xc01',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 490},
#                            {'endNote': 521,
#                             'flavor': [],
#                             'lyricStructure': u'Q1',
#                             'lyrics': u'\xe2leme ',
#                             'melodicStructure': u'\xc11',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 511},
#                            {'endNote': 533,
#                             'flavor': [],
#                             'lyricStructure': u'R1',
#                             'lyrics': u'al',
#                             'melodicStructure': u'\xc21',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 522},
#                            {'endNote': 551,
#                             'flavor': [],
#                             'lyricStructure': u'S1',
#                             'lyrics': u'danma hep ef',
#                             'melodicStructure': u'\xc31',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 534},
#                            {'endNote': 576,
#                             'flavor': [],
#                             'lyricStructure': u'G2',
#                             'lyrics': u'sanedir  ',
#                             'melodicStructure': u'\xc41',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'D1',
#                                           'melodicStructure': u'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 552},
#                            {'endNote': 603,
#                             'flavor': [],
#                             'lyricStructure': u'H1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': u'P2',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 577},
#                            {'endNote': 672,
#                             'flavor': [],
#                             'lyricStructure': u'T1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                             'melodicStructure': u'\xc51',
#                             'name': u'VOCAL_PHRASE',
#                             'sections': [{'lyricStructure': u'C1',
#                                           'melodicStructure': u'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_PHRASE',
#                             'startNote': 604}]},
#  'sections': [{'endNote': 105,
#                'lyricStructure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodicStructure': u'ARANAGME_1',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'startNote': 2},
#               {'endNote': 206,
#                'lyricStructure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodicStructure': u'ARANAGME_2',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'startNote': 106},
#               {'endNote': 288,
#                'lyricStructure': u'B1',
#                'lyrics': u'Ehl_i a\u015fk\u0131n ne\u015fveg\xe2h\u0131 k\xfb\u015fe_i meyhanedir  ',
#                'melodicStructure': u'B1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 207},
#               {'endNote': 387,
#                'lyricStructure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': u'C1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 289},
#               {'endNote': 488,
#                'lyricStructure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': u'C2',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 388},
#               {'endNote': 579,
#                'lyricStructure': u'D1',
#                'lyrics': u'G\xfcft_\xfc g\xfby_i \xe2leme aldanma hep efsanedir  ',
#                'melodicStructure': u'D1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 489},
#               {'endNote': 672,
#                'lyricStructure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': u'C3',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 580}],
#  'symbtr': 'kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi',
#  'tempo': {'unit': 'bpm', 'value': 72},
#  'tonic': u'G4',
#  'usul': {'mb_attribute': u'A\u011f\u0131raksak',
#           'mertebe': 4,
#           'mu2_name': u'A\u011f\u0131raksak',
#           'number_of_pulses': 9,
#           'symbtr_slug': 'agiraksak'},
#  'work': {'mbid': 'b43fd61e-522c-4af4-821d-db85722bf48c',
#           'mu2_title': u'Ehl-i A\u015fk\u0131n Ne\u015fveg\xe2h\u0131...',
#           'symbtr_slug': 'ehl-i_askin',
#           'title': u'Ehl-i A\u015fk\u0131n'}}
