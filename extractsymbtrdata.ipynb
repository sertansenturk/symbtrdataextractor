# %%
from symbtrdataextractor import extractor
from symbtrdataextractor import symbtrreader
import os
import json
import pprint

# %%
txtfilename = './examples/kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.txt'

scorename = os.path.splitext(os.path.basename(txtfilename))[0]
mbid = 'b43fd61e-522c-4af4-821d-db85722bf48c'

txtdata = extractor.extract(txtfilename, symbtrname=scorename, mbid=mbid, 
                         extractAllLabels=False, melody_sim_thres=0.25, 
                         lyrics_sim_thres=0.25, get_recording_rels=True)

# %%
mu2filename = './examples/kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.mu2'
mu2header = symbtrreader.readMu2Header(mu2filename)

# %%
if 'work' in txtdata.keys():
    mu2header['work'] = {'mu2_title':mu2header.pop('mu2_title')}
elif 'recording' in txtdata.keys():
    mu2header['recording'] = {'mu2_title':mu2header.pop('mu2_title')}
else:
    print '   Unknown title target.'
    mu2header.pop('mu2_title')
data = extractor.merge(txtdata, mu2header)

pprint.pprint(data)
# Out:
# {'composer': {'mbid': '9157531e-ba32-46e7-8c60-1a66c99f2ace',
#               'mu2_name': 'Tatyos Efendi',
#               'name': u'Tateos E\xf1serciyan',
#               'symbtr_slug': 'tatyos_efendi'},
#  'form': {'mb_attribute': u'\u015eark\u0131',
#           'mu2_name': '\xc5\x9eark\xc4\xb1',
#           'symbtr_slug': 'sarki'},
#  'genre': 'classical',
#  'key_signature': ['B4b5', 'E5b5', 'A4b5'],
#  'language': 'ota',
#  'lyricist': {'mbid': '125ec42a-7229-4250-afc5-e057484327fe',
#               'mu2_name': '?',
#               'name': '[unknown]'},
#  'makam': {'mb_attribute': u'K\xfcrdilihicazkar',
#            'mu2_name': 'K\xc3\xbcrd\xc3\xaelihicazk\xc3\xa2r',
#            'symbtr_slug': 'kurdilihicazkar'},
#  'notation': 'TSM',
#  'phrases': {'annotated': [{'endNote': 14,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'A1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 1},
#                            {'endNote': 20,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'B1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 15},
#                            {'endNote': 27,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'C1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 21},
#                            {'endNote': 38,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'D1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 28},
#                            {'endNote': 44,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'E1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 39},
#                            {'endNote': 59,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'F1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 45},
#                            {'endNote': 71,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'G1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 60},
#                            {'endNote': 80,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'H1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 72},
#                            {'endNote': 89,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'I1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 81},
#                            {'endNote': 97,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'J1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 90},
#                            {'endNote': 103,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'E1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_1',
#                                           'section_idx': 0}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 98},
#                            {'endNote': 118,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'A2',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 104},
#                            {'endNote': 124,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'B1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 119},
#                            {'endNote': 131,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'C1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 125},
#                            {'endNote': 142,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'D1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 132},
#                            {'endNote': 148,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'E1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 143},
#                            {'endNote': 163,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'F1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 149},
#                            {'endNote': 175,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'G1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 164},
#                            {'endNote': 184,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'H1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 176},
#                            {'endNote': 193,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'I1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 185},
#                            {'endNote': 201,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'J2',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 194},
#                            {'endNote': 205,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'K1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'INSTRUMENTAL',
#                                           'melodicStructure': u'ARANAGME_2',
#                                           'section_idx': 1}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 202},
#                            {'endNote': 207,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'L1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 206},
#                            {'endNote': 212,
#                             'flavor': [],
#                             'lyricStructure': 'B1',
#                             'lyrics': u'Ehl_i a\u015f',
#                             'melodicStructure': 'M1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 208},
#                            {'endNote': 226,
#                             'flavor': [],
#                             'lyricStructure': 'C1',
#                             'lyrics': u'k\u0131n ',
#                             'melodicStructure': 'N1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 213},
#                            {'endNote': 243,
#                             'flavor': [],
#                             'lyricStructure': 'D1',
#                             'lyrics': u'ne\u015fveg\xe2h\u0131 ',
#                             'melodicStructure': 'O1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 227},
#                            {'endNote': 268,
#                             'flavor': [],
#                             'lyricStructure': 'E1',
#                             'lyrics': u'k\xfb\u015fe_i mey',
#                             'melodicStructure': 'P1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 244},
#                            {'endNote': 280,
#                             'flavor': [],
#                             'lyricStructure': 'F1',
#                             'lyrics': u'hanedir  ',
#                             'melodicStructure': 'Q1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'B1',
#                                           'melodicStructure': 'B1',
#                                           'section_idx': 2}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 269},
#                            {'endNote': 292,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'R1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 281},
#                            {'endNote': 312,
#                             'flavor': [],
#                             'lyricStructure': 'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': 'S1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 293},
#                            {'endNote': 324,
#                             'flavor': [],
#                             'lyricStructure': 'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': 'T1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 313},
#                            {'endNote': 339,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'U1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 325},
#                            {'endNote': 367,
#                             'flavor': [],
#                             'lyricStructure': 'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': 'V1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 340},
#                            {'endNote': 378,
#                             'flavor': [],
#                             'lyricStructure': 'J1',
#                             'lyrics': u'm\xe2ne',
#                             'melodicStructure': 'W1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 368},
#                            {'endNote': 386,
#                             'flavor': [],
#                             'lyricStructure': 'K1',
#                             'lyrics': u'dir  ',
#                             'melodicStructure': 'X1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C1',
#                                           'section_idx': 3}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 379},
#                            {'endNote': 392,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'Y1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 387},
#                            {'endNote': 412,
#                             'flavor': [],
#                             'lyricStructure': 'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': 'S1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 393},
#                            {'endNote': 424,
#                             'flavor': [],
#                             'lyricStructure': 'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': 'T1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 413},
#                            {'endNote': 439,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'U1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 425},
#                            {'endNote': 467,
#                             'flavor': [],
#                             'lyricStructure': 'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': 'V1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 440},
#                            {'endNote': 480,
#                             'flavor': [],
#                             'lyricStructure': 'L1',
#                             'lyrics': u'm\xe2nedir  ',
#                             'melodicStructure': 'Z1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C2',
#                                           'section_idx': 4}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 468},
#                            {'endNote': 493,
#                             'flavor': [u'nev`eser@sol4'],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'a1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 481},
#                            {'endNote': 504,
#                             'flavor': [],
#                             'lyricStructure': 'M1',
#                             'lyrics': u'G\xfcft_\xfc g\xfby_i ',
#                             'melodicStructure': 'b1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 494},
#                            {'endNote': 515,
#                             'flavor': [u'nikriz@do5'],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'c1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 505},
#                            {'endNote': 536,
#                             'flavor': [],
#                             'lyricStructure': 'N1',
#                             'lyrics': u'\xe2leme al',
#                             'melodicStructure': 'd1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 516},
#                            {'endNote': 545,
#                             'flavor': [],
#                             'lyricStructure': 'O1',
#                             'lyrics': u'danma hep ',
#                             'melodicStructure': 'e1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 537},
#                            {'endNote': 559,
#                             'flavor': [],
#                             'lyricStructure': 'P1',
#                             'lyrics': u'ef',
#                             'melodicStructure': 'f1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 546},
#                            {'endNote': 571,
#                             'flavor': [],
#                             'lyricStructure': 'F2',
#                             'lyrics': u'sanedir  ',
#                             'melodicStructure': 'Q1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'D1',
#                                           'melodicStructure': 'D1',
#                                           'section_idx': 5}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 560},
#                            {'endNote': 583,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'R1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 572},
#                            {'endNote': 603,
#                             'flavor': [],
#                             'lyricStructure': 'G1',
#                             'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                             'melodicStructure': 'S1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 584},
#                            {'endNote': 615,
#                             'flavor': [],
#                             'lyricStructure': 'H1',
#                             'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                             'melodicStructure': 'T1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 604},
#                            {'endNote': 630,
#                             'flavor': [],
#                             'lyricStructure': 'INSTRUMENTAL',
#                             'lyrics': '',
#                             'melodicStructure': 'U1',
#                             'name': u'INSTRUMENTAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'INSTRUMENTAL_SECTION',
#                             'startNote': 616},
#                            {'endNote': 658,
#                             'flavor': [],
#                             'lyricStructure': 'I1',
#                             'lyrics': u'eyleyen pey',
#                             'melodicStructure': 'V1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 631},
#                            {'endNote': 669,
#                             'flavor': [],
#                             'lyricStructure': 'J1',
#                             'lyrics': u'm\xe2ne',
#                             'melodicStructure': 'W1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 659},
#                            {'endNote': 671,
#                             'flavor': [],
#                             'lyricStructure': 'K1',
#                             'lyrics': u'dir  ',
#                             'melodicStructure': 'g1',
#                             'name': u'VOCAL_SECTION',
#                             'sections': [{'lyricStructure': 'C1',
#                                           'melodicStructure': 'C3',
#                                           'section_idx': 6}],
#                             'slug': u'VOCAL_SECTION',
#                             'startNote': 670}]},
#  'sections': [{'endNote': 104,
#                'lyricStructure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodicStructure': u'ARANAGME_1',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'startNote': 1},
#               {'endNote': 205,
#                'lyricStructure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodicStructure': u'ARANAGME_2',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'startNote': 105},
#               {'endNote': 287,
#                'lyricStructure': 'B1',
#                'lyrics': u'Ehl_i a\u015fk\u0131n ne\u015fveg\xe2h\u0131 k\xfb\u015fe_i meyhanedir  ',
#                'melodicStructure': 'B1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 206},
#               {'endNote': 386,
#                'lyricStructure': 'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': 'C1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 288},
#               {'endNote': 487,
#                'lyricStructure': 'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': 'C2',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 387},
#               {'endNote': 578,
#                'lyricStructure': 'D1',
#                'lyrics': u'G\xfcft_\xfc g\xfby_i \xe2leme aldanma hep efsanedir  ',
#                'melodicStructure': 'D1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 488},
#               {'endNote': 671,
#                'lyricStructure': 'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodicStructure': 'C3',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'startNote': 579}],
#  'symbtr': 'kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi',
#  'tempo': {'unit': 'bpm', 'value': 72},
#  'tonic': u'G4',
#  'usul': {'mb_attribute': u'A\u011f\u0131raksak',
#           'mertebe': 4,
#           'mu2_name': 'A\xc4\x9f\xc4\xb1raksak',
#           'number_of_pulses': 9,
#           'symbtr_slug': 'agiraksak'},
#  'work': {'mbid': 'b43fd61e-522c-4af4-821d-db85722bf48c',
#           'mu2_title': 'Ehl-i A\xc5\x9fk\xc4\xb1n Ne\xc5\x9fveg\xc3\xa2h\xc4\xb1...',
#           'title': u'Ehl-i A\u015fk\u0131n'}}
