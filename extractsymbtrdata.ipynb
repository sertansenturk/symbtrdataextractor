# %%
from symbtrdataextractor.SymbTrDataExtractor import SymbTrDataExtractor
from symbtrdataextractor.reader.Mu2Reader import Mu2Reader
import os
import json
import pprint

# %%
txt_filename = os.path.join('sampledata','kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.txt')
auto_seg_file = os.path.join('sampledata','kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.autoSeg')

scorename = os.path.splitext(os.path.basename(txt_filename))[0]
mbid = 'b43fd61e-522c-4af4-821d-db85722bf48c'

# load automatic phrase segmentation: https://github.com/MTG/makam-symbolic-phrase-segmentation
auto_seg_bounds = json.load(open(auto_seg_file,'r'))['boundary_noteIdx']

# %%
extractor = SymbTrDataExtractor(extract_all_labels=False, melody_sim_thres=0.75, 
                                lyrics_sim_thres=0.75, get_recording_rels=False, 
                                crop_consec_bounds=True, print_warnings=True)
txt_data, is_data_valid = extractor.extract(txt_filename, symbtr_name=scorename, mbid=mbid, 
                                            segment_note_bound_idx=auto_seg_bounds)

# %%
mu2_filename = os.path.join('sampledata', 'kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi.mu2')
mu2_header, header_row, is_header_valid = Mu2Reader.read_header(mu2_filename, symbtr_name=scorename)

# %%
data = SymbTrDataExtractor.merge(txt_data, mu2_header)
pprint.pprint(data)
# Out:
# {'composer': {'mbid': '9157531e-ba32-46e7-8c60-1a66c99f2ace',
#               'mu2_name': u'Tatyos Efendi',
#               'name': u'Tateos E\xf1serciyan',
#               'symbtr_slug': 'tatyos_efendi'},
#  'duration': {'unit': 'second', 'value': 208.666},
#  'form': {'attribute_key': u'sarki',
#           'mb_attribute': u'\u015eark\u0131',
#           'mu2_name': u'\u015eark\u0131',
#           'source': 'http://musicbrainz.org/work/b43fd61e-522c-4af4-821d-db85722bf48c',
#           'symbtr_slug': 'sarki'},
#  'genre': 'classical',
#  'key_signature': [u'B4b5', u'E5b5', u'A4b5'],
#  'language': 'ota',
#  'lyricist': {'mbid': '125ec42a-7229-4250-afc5-e057484327fe',
#               'mu2_name': u'?',
#               'name': '[unknown]'},
#  'makam': {'attribute_key': u'kurdilihicazkar',
#            'mb_attribute': u'K\xfcrdilihicazkar',
#            'mu2_name': u'K\xfcrd\xeelihicazk\xe2r',
#            'source': 'http://musicbrainz.org/work/b43fd61e-522c-4af4-821d-db85722bf48c',
#            'symbtr_slug': 'kurdilihicazkar'},
#  'notation': u'TSM',
#  'number_of_notes': 672,
#  'phrase_annotations': [{'end_note': 15,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'A1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 2},
#                         {'end_note': 21,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'B1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 16},
#                         {'end_note': 28,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'C1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 22},
#                         {'end_note': 39,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'D1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 29},
#                         {'end_note': 45,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'E1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 40},
#                         {'end_note': 60,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'F1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 46},
#                         {'end_note': 72,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'G1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 61},
#                         {'end_note': 81,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'H1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 73},
#                         {'end_note': 90,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'I1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 82},
#                         {'end_note': 98,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'J1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 91},
#                         {'end_note': 104,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'E1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 99},
#                         {'end_note': 119,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'A1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_1',
#                                        'section_idx': 0},
#                                       {'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 105},
#                         {'end_note': 125,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'B1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 120},
#                         {'end_note': 132,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'C1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 126},
#                         {'end_note': 143,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'D1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 133},
#                         {'end_note': 149,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'E1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 144},
#                         {'end_note': 164,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'F1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 150},
#                         {'end_note': 176,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'G1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 165},
#                         {'end_note': 185,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'H1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 177},
#                         {'end_note': 194,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'I1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 186},
#                         {'end_note': 202,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'J2',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 195},
#                         {'end_note': 206,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'K1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                        'melodic_structure': u'ARANAGME_2',
#                                        'section_idx': 1}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 203},
#                         {'end_note': 208,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'L1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 207},
#                         {'end_note': 213,
#                          'flavor': [],
#                          'lyric_structure': u'B1',
#                          'lyrics': u'Ehl_i a\u015f',
#                          'melodic_structure': u'M1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 209},
#                         {'end_note': 227,
#                          'flavor': [],
#                          'lyric_structure': u'C1',
#                          'lyrics': u'k\u0131n ',
#                          'melodic_structure': u'N1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 214},
#                         {'end_note': 244,
#                          'flavor': [],
#                          'lyric_structure': u'D1',
#                          'lyrics': u'ne\u015fveg\xe2h\u0131 ',
#                          'melodic_structure': u'O1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 228},
#                         {'end_note': 269,
#                          'flavor': [],
#                          'lyric_structure': u'E1',
#                          'lyrics': u'k\xfb\u015fe_i mey',
#                          'melodic_structure': u'P1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 245},
#                         {'end_note': 281,
#                          'flavor': [],
#                          'lyric_structure': u'F1',
#                          'lyrics': u'hanedir  ',
#                          'melodic_structure': u'Q1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 270},
#                         {'end_note': 293,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'R1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'B1',
#                                        'melodic_structure': u'B1',
#                                        'section_idx': 2},
#                                       {'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 282},
#                         {'end_note': 313,
#                          'flavor': [],
#                          'lyric_structure': u'G1',
#                          'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                          'melodic_structure': u'S1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 294},
#                         {'end_note': 325,
#                          'flavor': [],
#                          'lyric_structure': u'H1',
#                          'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                          'melodic_structure': u'T1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 314},
#                         {'end_note': 340,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'U1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 326},
#                         {'end_note': 368,
#                          'flavor': [],
#                          'lyric_structure': u'I1',
#                          'lyrics': u'eyleyen pey',
#                          'melodic_structure': u'V1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 341},
#                         {'end_note': 379,
#                          'flavor': [],
#                          'lyric_structure': u'J1',
#                          'lyrics': u'm\xe2ne',
#                          'melodic_structure': u'W1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 369},
#                         {'end_note': 387,
#                          'flavor': [],
#                          'lyric_structure': u'K1',
#                          'lyrics': u'dir  ',
#                          'melodic_structure': u'X1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C1',
#                                        'section_idx': 3}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 380},
#                         {'end_note': 393,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'Y1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 388},
#                         {'end_note': 413,
#                          'flavor': [],
#                          'lyric_structure': u'G1',
#                          'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                          'melodic_structure': u'S1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 394},
#                         {'end_note': 425,
#                          'flavor': [],
#                          'lyric_structure': u'H1',
#                          'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                          'melodic_structure': u'T1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 414},
#                         {'end_note': 440,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'U1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 426},
#                         {'end_note': 468,
#                          'flavor': [],
#                          'lyric_structure': u'I1',
#                          'lyrics': u'eyleyen pey',
#                          'melodic_structure': u'V1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 441},
#                         {'end_note': 481,
#                          'flavor': [],
#                          'lyric_structure': u'L1',
#                          'lyrics': u'm\xe2nedir  ',
#                          'melodic_structure': u'Z1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 469},
#                         {'end_note': 494,
#                          'flavor': [u'nev`eser@sol4'],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'\xc01',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C2',
#                                        'section_idx': 4},
#                                       {'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 482},
#                         {'end_note': 505,
#                          'flavor': [],
#                          'lyric_structure': u'M1',
#                          'lyrics': u'G\xfcft_\xfc g\xfby_i ',
#                          'melodic_structure': u'\xc11',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 495},
#                         {'end_note': 516,
#                          'flavor': [u'nikriz@do5'],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'\xc21',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 506},
#                         {'end_note': 537,
#                          'flavor': [],
#                          'lyric_structure': u'N1',
#                          'lyrics': u'\xe2leme al',
#                          'melodic_structure': u'\xc31',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 517},
#                         {'end_note': 546,
#                          'flavor': [],
#                          'lyric_structure': u'O1',
#                          'lyrics': u'danma hep ',
#                          'melodic_structure': u'\xc41',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 538},
#                         {'end_note': 560,
#                          'flavor': [],
#                          'lyric_structure': u'P1',
#                          'lyrics': u'ef',
#                          'melodic_structure': u'\xc51',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 547},
#                         {'end_note': 572,
#                          'flavor': [],
#                          'lyric_structure': u'F2',
#                          'lyrics': u'sanedir  ',
#                          'melodic_structure': u'Q1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 561},
#                         {'end_note': 584,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'R1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'D1',
#                                        'melodic_structure': u'D1',
#                                        'section_idx': 5},
#                                       {'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 573},
#                         {'end_note': 604,
#                          'flavor': [],
#                          'lyric_structure': u'G1',
#                          'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                          'melodic_structure': u'S1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 585},
#                         {'end_note': 616,
#                          'flavor': [],
#                          'lyric_structure': u'H1',
#                          'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                          'melodic_structure': u'T1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 605},
#                         {'end_note': 631,
#                          'flavor': [],
#                          'lyric_structure': 'INSTRUMENTAL',
#                          'lyrics': '',
#                          'melodic_structure': u'U1',
#                          'name': u'INSTRUMENTAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'INSTRUMENTAL_PHRASE',
#                          'start_note': 617},
#                         {'end_note': 659,
#                          'flavor': [],
#                          'lyric_structure': u'I1',
#                          'lyrics': u'eyleyen pey',
#                          'melodic_structure': u'V1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 632},
#                         {'end_note': 670,
#                          'flavor': [],
#                          'lyric_structure': u'J1',
#                          'lyrics': u'm\xe2ne',
#                          'melodic_structure': u'W1',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 660},
#                         {'end_note': 672,
#                          'flavor': [],
#                          'lyric_structure': u'K1',
#                          'lyrics': u'dir  ',
#                          'melodic_structure': u'\xc61',
#                          'name': u'VOCAL_PHRASE',
#                          'sections': [{'lyric_structure': u'C1',
#                                        'melodic_structure': u'C3',
#                                        'section_idx': 6}],
#                          'slug': u'VOCAL_PHRASE',
#                          'start_note': 671}],
#  'recordings': [],
#  'rhythmic_structure': [{'endNote': 672,
#                          'startNote': 1,
#                          'tempo': {'unit': 'bpm', 'value': 72},
#                          'usul': {'attribute_key': u'agiraksak',
#                                   'mertebe': 4,
#                                   'mu2_name': u'A\u011f\u0131raksak',
#                                   'number_of_pulses': 9,
#                                   'symbtr_internal_id': 22}}],
#  'scores': [u'kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi'],
#  'sections': [{'end_note': 105,
#                'lyric_structure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodic_structure': u'ARANAGME_1',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'start_note': 2},
#               {'end_note': 206,
#                'lyric_structure': 'INSTRUMENTAL',
#                'lyrics': '',
#                'melodic_structure': u'ARANAGME_2',
#                'name': u'ARANA\u011eME',
#                'slug': u'ARANAGME',
#                'start_note': 106},
#               {'end_note': 288,
#                'lyric_structure': u'B1',
#                'lyrics': u'Ehl_i a\u015fk\u0131n ne\u015fveg\xe2h\u0131 k\xfb\u015fe_i meyhanedir  ',
#                'melodic_structure': u'B1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'start_note': 207},
#               {'end_note': 387,
#                'lyric_structure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodic_structure': u'C1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'start_note': 289},
#               {'end_note': 488,
#                'lyric_structure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodic_structure': u'C2',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'start_note': 388},
#               {'end_note': 579,
#                'lyric_structure': u'D1',
#                'lyrics': u'G\xfcft_\xfc g\xfby_i \xe2leme aldanma hep efsanedir  ',
#                'melodic_structure': u'D1',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'start_note': 489},
#               {'end_note': 672,
#                'lyric_structure': u'C1',
#                'lyrics': u'S\xe2kiy\xe2 u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                'melodic_structure': u'C3',
#                'name': u'VOCAL_SECTION',
#                'slug': u'VOCAL_SECTION',
#                'start_note': 580}],
#  'segmentations': [{'end_note': 5,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'A1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_1',
#                                   'section_idx': 0}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 2},
#                    {'end_note': 14,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'B1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_1',
#                                   'section_idx': 0}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 6},
#                    {'end_note': 40,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'C1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_1',
#                                   'section_idx': 0}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 15},
#                    {'end_note': 98,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'D1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_1',
#                                   'section_idx': 0}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 41},
#                    {'end_note': 107,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'E1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_1',
#                                   'section_idx': 0},
#                                  {'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 99},
#                    {'end_note': 133,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'F1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 108},
#                    {'end_note': 186,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'G1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 134},
#                    {'end_note': 189,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'H1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 187},
#                    {'end_note': 203,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'I1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 190},
#                    {'end_note': 219,
#                     'flavor': [],
#                     'lyric_structure': u'B1',
#                     'lyrics': u'Ehl_i a\u015fk\u0131n ',
#                     'melodic_structure': u'J1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': 'INSTRUMENTAL',
#                                   'melodic_structure': u'ARANAGME_2',
#                                   'section_idx': 1},
#                                  {'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 204},
#                    {'end_note': 229,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'K1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 220},
#                    {'end_note': 242,
#                     'flavor': [],
#                     'lyric_structure': u'C1',
#                     'lyrics': u'ne\u015fveg\xe2h\u0131 ',
#                     'melodic_structure': u'L1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 230},
#                    {'end_note': 253,
#                     'flavor': [],
#                     'lyric_structure': u'D1',
#                     'lyrics': u'k\xfb\u015fe_i ',
#                     'melodic_structure': u'M1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 243},
#                    {'end_note': 265,
#                     'flavor': [],
#                     'lyric_structure': u'E1',
#                     'lyrics': u'mey',
#                     'melodic_structure': u'N1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 254},
#                    {'end_note': 283,
#                     'flavor': [],
#                     'lyric_structure': u'F1',
#                     'lyrics': u'hanedir  ',
#                     'melodic_structure': u'O1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 266},
#                    {'end_note': 308,
#                     'flavor': [],
#                     'lyric_structure': u'G1',
#                     'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                     'melodic_structure': u'P1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'B1',
#                                   'melodic_structure': u'B1',
#                                   'section_idx': 2},
#                                  {'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 284},
#                    {'end_note': 335,
#                     'flavor': [],
#                     'lyric_structure': u'H1',
#                     'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                     'melodic_structure': u'Q1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 309},
#                    {'end_note': 346,
#                     'flavor': [],
#                     'lyric_structure': u'I1',
#                     'lyrics': u'eyleyen ',
#                     'melodic_structure': u'R1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 336},
#                    {'end_note': 358,
#                     'flavor': [],
#                     'lyric_structure': u'J1',
#                     'lyrics': u'pey',
#                     'melodic_structure': u'S1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 347},
#                    {'end_note': 376,
#                     'flavor': [],
#                     'lyric_structure': u'K1',
#                     'lyrics': u'm\xe2',
#                     'melodic_structure': u'T1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 359},
#                    {'end_note': 401,
#                     'flavor': [],
#                     'lyric_structure': u'L1',
#                     'lyrics': u'nedir  S\xe2kiy\xe2 ',
#                     'melodic_structure': u'U1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C1',
#                                   'section_idx': 3},
#                                  {'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 377},
#                    {'end_note': 428,
#                     'flavor': [],
#                     'lyric_structure': u'H2',
#                     'lyrics': u'u\u015f\u015f\xe2k\u0131 dil\u015f\xe2d ',
#                     'melodic_structure': u'V1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 402},
#                    {'end_note': 439,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'W1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 429},
#                    {'end_note': 451,
#                     'flavor': [],
#                     'lyric_structure': u'M1',
#                     'lyrics': u'eyleyen pey',
#                     'melodic_structure': u'X1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 440},
#                    {'end_note': 469,
#                     'flavor': [],
#                     'lyric_structure': 'INSTRUMENTAL',
#                     'lyrics': '',
#                     'melodic_structure': u'Y1',
#                     'name': u'INSTRUMENTAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4}],
#                     'slug': u'INSTRUMENTAL_SEGMENT',
#                     'start_note': 452},
#                    {'end_note': 489,
#                     'flavor': [u'nev`eser@sol4'],
#                     'lyric_structure': u'N1',
#                     'lyrics': u'm\xe2nedir  ',
#                     'melodic_structure': u'Z1',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C2',
#                                   'section_idx': 4},
#                                  {'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 470},
#                    {'end_note': 510,
#                     'flavor': [u'nikriz@do5'],
#                     'lyric_structure': u'O1',
#                     'lyrics': u'G\xfcft_\xfc g\xfby_i ',
#                     'melodic_structure': u'\xc01',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 490},
#                    {'end_note': 521,
#                     'flavor': [],
#                     'lyric_structure': u'P1',
#                     'lyrics': u'\xe2leme ',
#                     'melodic_structure': u'\xc11',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 511},
#                    {'end_note': 533,
#                     'flavor': [],
#                     'lyric_structure': u'Q1',
#                     'lyrics': u'al',
#                     'melodic_structure': u'\xc21',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 522},
#                    {'end_note': 551,
#                     'flavor': [],
#                     'lyric_structure': u'R1',
#                     'lyrics': u'danma hep ef',
#                     'melodic_structure': u'\xc31',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 534},
#                    {'end_note': 576,
#                     'flavor': [],
#                     'lyric_structure': u'F2',
#                     'lyrics': u'sanedir  ',
#                     'melodic_structure': u'\xc41',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 552},
#                    {'end_note': 603,
#                     'flavor': [],
#                     'lyric_structure': u'G1',
#                     'lyrics': u'S\xe2kiy\xe2 u\u015f',
#                     'melodic_structure': u'P2',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'D1',
#                                   'melodic_structure': u'D1',
#                                   'section_idx': 5},
#                                  {'lyric_structure': u'C1',
#                                   'melodic_structure': u'C3',
#                                   'section_idx': 6}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 577},
#                    {'end_note': 672,
#                     'flavor': [],
#                     'lyric_structure': u'S1',
#                     'lyrics': u'\u015f\xe2k\u0131 dil\u015f\xe2d eyleyen peym\xe2nedir  ',
#                     'melodic_structure': u'\xc51',
#                     'name': u'VOCAL_SEGMENT',
#                     'sections': [{'lyric_structure': u'C1',
#                                   'melodic_structure': u'C3',
#                                   'section_idx': 6}],
#                     'slug': u'VOCAL_SEGMENT',
#                     'start_note': 604}],
#  'symbtr': 'kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi',
#  'tempo': {'unit': 'bpm', 'value': 72},
#  'tonic': u'G4',
#  'usul': {'attribute_key': u'agiraksak',
#           'mb_attribute': u'A\u011f\u0131raksak',
#           'mertebe': 4,
#           'mu2_name': u'A\u011f\u0131raksak',
#           'number_of_pulses': 9,
#           'source': 'http://musicbrainz.org/work/b43fd61e-522c-4af4-821d-db85722bf48c',
#           'symbtr_slug': 'agiraksak'},
#  'work': {'mbid': 'b43fd61e-522c-4af4-821d-db85722bf48c',
#           'mu2_title': u'Ehl-i A\u015fk\u0131n Ne\u015fveg\xe2h\u0131...',
#           'symbtr_slug': 'ehl-i_askin',
#           'title': u'Ehl-i A\u015fk\u0131n'}}
